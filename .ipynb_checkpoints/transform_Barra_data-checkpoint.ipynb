# %%
import os
import data_processing_tool as dpt
from datetime import timedelta, date, datetime
# import args_parameter as args
import torch,torchvision
import numpy as np

from torch.utils.data import Dataset,random_split
from torchvision import datasets, models, transforms

import time
import xarray as xr

import data_processing_tool as dpt

# %%
import argparse
parser = argparse.ArgumentParser(description='BARRA_R and ACCESS-S!')
parser.add_argument('--args_test', type=int, default=0,
                        help='testing parameters input')
parser.add_argument('--debug', action='store_true',
                    help='Enables debug mode')
parser.add_argument('--template', default='.',
                    help='You can set various templates in option.py')

# Hardware specifications
parser.add_argument('--n_threads', type=int, default=0,
                    help='number of threads for data loading')
parser.add_argument('--cpu', action='store_true',
                    help='use cpu only')
parser.add_argument('--n_GPUs', type=int, default=1,
                    help='number of GPUs')
parser.add_argument('--seed', type=int, default=1,
                    help='random seed')

# Data specifications
parser.add_argument('--pr', type=bool, 
                default=True,
                help='add-on pr?')

parser.add_argument('--dem', type=bool, 
                default=False,
                help='add-on dem?') 
parser.add_argument('--psl', type=bool, 
                default=False,
                help='add-on psl?') 
parser.add_argument('--zg', type=bool, 
                default=False,
                help='add-on zg?') 
parser.add_argument('--tasmax', type=bool, 
                default=False,
                help='add-on tasmax?') 
parser.add_argument('--tasmin', type=bool, 
                default=False,
                help='add-on tasmin?')

parser.add_argument('--leading_time_we_use', type=int, 
                default=7,
                help='add-on tasmin?')




parser.add_argument('--ensemble', type=int, 
                default=2,
                help='total ensambles is 11') 


parser.add_argument('--channels', type=float, 
                    default=0,
                    help='channel of data_input must') 
#[111.85, 155.875, -44.35, -9.975]
parser.add_argument('--domain', type=list, 
                    default=[112.9, 154.25, -43.7425, -9.0],
                    help='dataset directory')    


parser.add_argument('--file_ACCESS_dir', type=str, 
                    default="F:/climate/access-s1/pr/daily/",

                    help='dataset directory')
parser.add_argument('--file_BARRA_dir', type=str, 
                    default="C:/Users/JIA059/barra/",
                    help='dataset directory')

parser.add_argument('--file_DEM_dir', type=str, 
                    default="../DEM/",
                    help='dataset directory')

parser.add_argument('--nine2nine', type=bool, 
                    default=True,
                    help='whether rainfall acculate from 9am to 9am')
parser.add_argument('--date_minus_one', type=int, 
                    default=1,
                    help='whether rainfall acculate from yesterday(1)/today(0) 9am to tody/tomorrow 9am')


parser.add_argument('--dir_demo', type=str, default='../test',
                    help='demo image directory')
#     parser.add_argument('--data_train', type=str, default='BARRA_R',
#                         help='train dataset name')
#     parser.add_argument('--data_test', type=str, default='DIV2K',
#                         help='test dataset name')
parser.add_argument('--benchmark_noise', action='store_true',
                    help='use noisy benchmark sets')
parser.add_argument('--n_train', type=int, default=800,
                    help='number of training set')
parser.add_argument('--n_val', type=int, default=10,
                    help='number of validation set')
parser.add_argument('--offset_val', type=int, default=800,
                    help='validation index offest')
parser.add_argument('--ext', type=str, default='sep',
                    help='dataset file extension')
parser.add_argument('--scale', default='4',
                    help='super resolution scale')
parser.add_argument('--patch_size', type=int, default=192,
                    help='output patch size')
#??????????????????????????????????????????????????
parser.add_argument('--rgb_range', type=int, default=400,
                    help='maximum value of RGB')
parser.add_argument('--n_colors', type=int, default=3,
                    help='number of color channels to use')
parser.add_argument('--noise', type=str, default='.',
                    help='Gaussian noise std.')
parser.add_argument('--chop', action='store_true',
                    help='enable memory-efficient forward')

# Model specifications
parser.add_argument('--model', default='RCAN',
                    help='model name')

parser.add_argument('--act', type=str, default='relu',
                    help='activation function')
parser.add_argument('--pre_train', type=str, default='.',
                    help='pre-trained model directory')
parser.add_argument('--extend', type=str, default='.',
                    help='pre-trained model directory')
parser.add_argument('--n_resblocks', type=int, default=20,
                    help='number of residual blocks')
parser.add_argument('--n_feats', type=int, default=64,
                    help='number of feature maps')
parser.add_argument('--res_scale', type=float, default=1,
                    help='residual scaling')
parser.add_argument('--shift_mean', default=True,
                    help='subtract pixel mean from the input')
parser.add_argument('--precision', type=str, default='single',
                    choices=('single', 'half','double'),
                    help='FP precision for test (single | half)')

# Training specifications

parser.add_argument('--train_name', type=str, default='temp01',
                    help='the trainning name of the set')
parser.add_argument('--reset', action='store_true',
                    help='reset the training')
parser.add_argument('--test_every', type=int, default=1000,
                    help='do test per every N batches')
parser.add_argument('--epochs', type=int, default=300,
                    help='number of epochs to train')
parser.add_argument('--batch_size', type=int, default=2,
                    help='input batch size for training')
parser.add_argument('--split_batch', type=int, default=1,
                    help='split the batch into smaller chunks')
parser.add_argument('--self_ensemble', action='store_true',
                    help='use self-ensemble method for test')
parser.add_argument('--test_only', action='store_true',
                    help='set this option to test the model')
parser.add_argument('--gan_k', type=int, default=1,
                    help='k value for adversarial loss')

# Optimization specifications
parser.add_argument('--lr', type=float, default=1e-4,
                    help='learning rate')
parser.add_argument('--lr_decay', type=int, default=200,
                    help='learning rate decay per N epochs')
parser.add_argument('--decay_type', type=str, default='step',
                    help='learning rate decay type')
parser.add_argument('--gamma', type=float, default=0.5,
                    help='learning rate decay factor for step decay')
parser.add_argument('--optimizer', default='ADAM',
                    choices=('SGD', 'ADAM', 'RMSprop'),
                    help='optimizer to use (SGD | ADAM | RMSprop)')
parser.add_argument('--momentum', type=float, default=0.9,
                    help='SGD momentum')
parser.add_argument('--beta1', type=float, default=0.9,
                    help='ADAM beta1')
parser.add_argument('--beta2', type=float, default=0.999,
                    help='ADAM beta2')
parser.add_argument('--epsilon', type=float, default=1e-8,
                    help='ADAM epsilon for numerical stability')
parser.add_argument('--weight_decay', type=float, default=0,
                    help='weight decay')

# Loss specifications
parser.add_argument('--loss', type=str, default='1*L1',
                    help='loss function configuration')
parser.add_argument('--skip_threshold', type=float, default='1e6',
                    help='skipping batch that has large error')

# Log specifications
parser.add_argument('--save', type=str, default='RCAN',
                    help='file name to save')
parser.add_argument('--load', type=str, default='.',
                    help='file name to load')
parser.add_argument('--resume', type=int, default=0,
                    help='resume from specific checkpoint')
parser.add_argument('--print_model', action='store_true',
                    help='print model')
parser.add_argument('--save_models', action='store_true',
                    help='save all intermediate models')
parser.add_argument('--print_every', type=int, default=100,
                    help='how many batches to wait before logging training status')
parser.add_argument('--save_results', action='store_true',
                    help='save output results')

# New options
parser.add_argument('--n_resgroups', type=int, default=10,
                    help='number of residual groups')
parser.add_argument('--reduction', type=int, default=16,
                    help='number of feature maps reduction')
parser.add_argument('--testpath', type=str, default='../test/DIV2K_val_LR_our',
                    help='dataset directory for testing')
parser.add_argument('--testset', type=str, default='Set5',
                    help='dataset name for testing')
parser.add_argument('--degradation', type=str, default='BI',
                    help='degradation model: BI, BD')
# args = []
# args = parser.parse_known_args()[0]
import platform 
sys = platform.system()

if sys == "Windows":
    args = parser.parse_args(args=[])
else:
    args = parser.parse_args()

# args = parser.parse_args()


#     template.set_template(args)

# args = parser.parse_args()

args.scale = list(map(lambda x: int(x), args.scale.split('+')))

if args.epochs == 0:
    args.epochs = 1e8

for arg in vars(args):
    if vars(args)[arg] == 'True':
        vars(args)[arg] = True
    elif vars(args)[arg] == 'False':
        vars(args)[arg] = False

# %%
class ACCESS_BARRA_v4(Dataset):
    '''
    scale is size(hr)=size(lr)*scale
    version_3_documention: compare with ver1, I modify:
    1. access file is created on getitem,the file list is access_date,barra,barra_date,time_leading
      in order to read more data like zg etc. more easier, we change access_filepath to access_date

    2. in ver., norm the every inputs 
   
    '''
    def __init__(self,start_date=date(1990, 1, 1),end_date=date(1990,12 , 31),regin="AUS",transform=None,train=True,args=None):
        print("=> BARRA_R & ACCESS_S1 loading")
        print("=> from "+start_date.strftime("%Y/%m/%d")+" to "+end_date.strftime("%Y/%m/%d")+"")
        self.file_BARRA_dir = args.file_BARRA_dir
        self.file_ACCESS_dir = args.file_ACCESS_dir
        self.args=args
        
        self.transform = transform
        self.start_date = start_date
        self.end_date = end_date
        
        self.scale = args.scale[0]
        self.regin = regin
        self.leading_time=217
        self.leading_time_we_use=args.leading_time_we_use

        self.ensemble_access=['e01','e02','e03','e04','e05','e06','e07','e08','e09','e10','e11']
        self.ensemble=[]
        for i in range(args.ensemble):
            self.ensemble.append(self.ensemble_access[i])
                
        self.dates = self.date_range(start_date, end_date)
        
        
        self.filename_list=self.get_filename_with_time_order(args.file_ACCESS_dir+"pr/daily/")
        if not os.path.exists(args.file_ACCESS_dir+"pr/daily/"):
            print(args.file_ACCESS_dir+"pr/daily/")
            print("no file or no permission")
        
        
        _,_,_,date_for_BARRA,time_leading=self.filename_list[0]
        if not os.path.exists("/g/data/ma05/BARRA_R/v1/forecast/spec/accum_prcp/1990/01/accum_prcp-fc-spec-PT1H-BARRA_R-v1-19900109T0600Z.sub.nc"):
            print(self.file_BARRA_dir)
            print("no file or no permission!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        data_high=dpt.read_barra_data_fc(self.file_BARRA_dir,date_for_BARRA,nine2nine=True)
        data_exp=dpt.map_aust(data_high,domain=args.domain,xrarray=True)#,domain=domain)
        self.lat=data_exp["lat"]
        self.lon=data_exp["lon"]
        self.shape=(79,94)
        if self.args.dem:
            data_dem=dpt.add_lat_lon( dpt.read_dem(args.file_DEM_dir+"dem-9s1.tif"))
            self.dem_data=dpt.interp_tensor_2d(dpt.map_aust_old(data_dem,xrarray=False) ,self.shape )
        

        
    def __len__(self):
        return len(self.filename_list)
    

    def date_range(self,start_date, end_date):
        """This function takes a start date and an end date as datetime date objects.
        It returns a list of dates for each date in order starting at the first date and ending with the last date"""
        return [start_date + timedelta(x) for x in range((end_date - start_date).days + 1)]

    
    def get_filename_with_no_time_order(self,rootdir):
        '''get filename first and generate label '''
        _files = []
        list = os.listdir(rootdir) #列出文件夹下所有的目录与文件
        for i in range(0,len(list)):
            path = os.path.join(rootdir,list[i])
            if os.path.isdir(path):
                _files.extend(self.get_filename_with_no_time_order(path))
            if os.path.isfile(path):
                if path[-3:]==".nc":
                    _files.append(path)
        return _files
    
    def get_filename_with_time_order(self,rootdir):
        '''get filename first and generate label ,one different w'''
        _files = []
        for en in self.ensemble:
            for date in self.dates:
                
                    
                
#                 filename="da_pr_"+date.strftime("%Y%m%d")+"_"+en+".nc"cd
                access_path=rootdir+en+"/"+"da_pr_"+date.strftime("%Y%m%d")+"_"+en+".nc"
                if os.path.exists(access_path):
                    for i in range(self.leading_time_we_use):
                        if date==self.end_date and i==1:
                            break
                        path=[access_path]
                        path.append(en)
                        barra_date=date+timedelta(i)
                        path.append(date)
                        path.append(barra_date)
                        path.append(i)
                        _files.append(path)
    
    #最后去掉第一行，然后shuffle
        if self.args.nine2nine and self.args.date_minus_one==1:
            del _files[0]
        return _files

    

        
    def __getitem__(self, idx):
        '''
        from filename idx get id
        return lr,hr
        '''
        t=time.time()

        access_filename_pr,en,access_date,date_for_BARRA,time_leading=self.filename_list[idx]

        data_high=dpt.read_barra_data_fc(self.file_BARRA_dir,date_for_BARRA,nine2nine=True)
        label=dpt.map_aust(data_high,domain=self.args.domain,xrarray=False)#,domain=domain)
        return label

# %%
sys = platform.system()

if sys == "Windows":
    init_date=date(1970, 1, 1)
    start_date=date(1990, 1, 2)
    end_date=date(1990,12,15) #if 929 is true we should substract 1 day   
    args.file_ACCESS_dir="H:/climate/access-s1/" 
    args.file_BARRA_dir="D:/dataset/accum_prcp/"
#         args.file_ACCESS_dir="E:/climate/access-s1/"
#         args.file_BARRA_dir="C:/Users/JIA059/barra/"
    args.file_DEM_dir="../DEM/"
else:
    args.file_ACCESS_dir_pr="/g/data/ub7/access-s1/hc/raw_model/atmos/pr/daily/"
    args.file_ACCESS_dir="/g/data/ub7/access-s1/hc/raw_model/atmos/"
    # training_name="temp01"
    args.file_BARRA_dir="/g/data/ma05/BARRA_R/v1/forecast/spec/accum_prcp/"
args.dem=1
args.tasmax=0
args.channels=0
if args.pr:
    args.channels+=1
if args.zg:
    args.channels+=1
if args.psl:
    args.channels+=1
if args.tasmax:
    args.channels+=1
if args.tasmin:
    args.channels+=1
if args.dem:
    args.channels+=1
access_rgb_mean= 2.9067910245780248e-05*86400

leading_time=217
args.leading_time_we_use=1
args.ensemble=11

# %%
dates=[start_date + timedelta(x) for x in range((end_date - start_date).days + 1)]
leading_time_we_use=7
def get_filename_with_time_order(rootdir):
    '''get filename first and generate label ,one different w'''
    _files = []
    for en in ["e01"]:
        for date in dates:



#                 filename="da_pr_"+date.strftime("%Y%m%d")+"_"+en+".nc"cd
            access_path=rootdir+en+"/"+"da_pr_"+date.strftime("%Y%m%d")+"_"+en+".nc"
            print(access_path)
            if os.path.exists(access_path):
                for i in range(leading_time_we_use):
                    if date==end_date and i==1:
                        break
                    path=[access_path]
                    path.append(en)
                    barra_date=date+timedelta(i)
                    path.append(date)
                    path.append(barra_date)
                    path.append(i)
                    _files.append(path)
    if self.args.nine2nine and self.args.date_minus_one==1:
        del _files[0]
    return _files

# %%
filename_list=get_filename_with_time_order(args.file_ACCESS_dir+"pr/daily/")
# Out:
# H:/climate/access-s1/pr/daily/e01/da_pr_19900102_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900103_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900104_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900105_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900106_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900107_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900108_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900109_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900110_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900111_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900112_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900113_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900114_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900115_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900116_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900117_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900118_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900119_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900120_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900121_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900122_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900123_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900124_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900125_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900126_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900127_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900128_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900129_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900130_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900131_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900201_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900202_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900203_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900204_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900205_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900206_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900207_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900208_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900209_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900210_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900211_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900212_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900213_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900214_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900215_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900216_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900217_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900218_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900219_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900220_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900221_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900222_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900223_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900224_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900225_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900226_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900227_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900228_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900301_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900302_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900303_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900304_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900305_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900306_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900307_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900308_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900309_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900310_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900311_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900312_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900313_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900314_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900315_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900316_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900317_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900318_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900319_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900320_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900321_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900322_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900323_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900324_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900325_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900326_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900327_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900328_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900329_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900330_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900331_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900401_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900402_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900403_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900404_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900405_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900406_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900407_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900408_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900409_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900410_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900411_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900412_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900413_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900414_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900415_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900416_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900417_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900418_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900419_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900420_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900421_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900422_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900423_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900424_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900425_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900426_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900427_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900428_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900429_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900430_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900501_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900502_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900503_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900504_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900505_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900506_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900507_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900508_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900509_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900510_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900511_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900512_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900513_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900514_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900515_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900516_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900517_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900518_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900519_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900520_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900521_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900522_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900523_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900524_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900525_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900526_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900527_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900528_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900529_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900530_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900531_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900601_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900602_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900603_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900604_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900605_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900606_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900607_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900608_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900609_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900610_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900611_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900612_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900613_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900614_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900615_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900616_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900617_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900618_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900619_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900620_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900621_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900622_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900623_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900624_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900625_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900626_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900627_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900628_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900629_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900630_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900701_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900702_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900703_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900704_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900705_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900706_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900707_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900708_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900709_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900710_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900711_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900712_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900713_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900714_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900715_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900716_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900717_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900718_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900719_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900720_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900721_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900722_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900723_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900724_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900725_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900726_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900727_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900728_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900729_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900730_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900731_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900801_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900802_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900803_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900804_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900805_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900806_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900807_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900808_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900809_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900810_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900811_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900812_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900813_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900814_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900815_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900816_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900817_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900818_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900819_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900820_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900821_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900822_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900823_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900824_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900825_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900826_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900827_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900828_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900829_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900830_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900831_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900901_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900902_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900903_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900904_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900905_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900906_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900907_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900908_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900909_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900910_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900911_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900912_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900913_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900914_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900915_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900916_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900917_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900918_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900919_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900920_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900921_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900922_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900923_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900924_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900925_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900926_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900927_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900928_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900929_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19900930_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901001_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901002_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901003_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901004_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901005_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901006_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901007_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901008_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901009_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901010_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901011_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901012_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901013_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901014_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901015_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901016_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901017_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901018_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901019_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901020_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901021_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901022_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901023_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901024_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901025_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901026_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901027_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901028_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901029_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901030_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901031_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901101_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901102_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901103_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901104_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901105_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901106_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901107_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901108_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901109_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901110_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901111_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901112_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901113_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901114_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901115_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901116_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901117_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901118_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901119_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901120_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901121_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901122_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901123_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901124_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901125_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901126_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901127_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901128_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901129_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901130_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901201_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901202_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901203_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901204_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901205_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901206_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901207_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901208_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901209_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901210_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901211_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901212_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901213_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901214_e01.nc
# H:/climate/access-s1/pr/daily/e01/da_pr_19901215_e01.nc
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-4224f575eab8> in <module>
# ----> 1 filename_list=get_filename_with_time_order(args.file_ACCESS_dir+"pr/daily/")
#
# <ipython-input-30-46580fac3974> in get_filename_with_time_order(rootdir)
#      23                     path.append(i)
#      24                     _files.append(path)
# ---> 25     if self.args.nine2nine and self.args.date_minus_one==1:
#      26         del _files[0]
#      27     return _files
#
# NameError: name 'self' is not defined

# %%
print(filename_list)
# Out:
# None
